# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }

# %%
df=pd.DataFrame(dict1)

# %%
df.head()
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male

# %% [markdown]
# 1.Display top 3 data

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# 2.display last 3 rows

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# 3.find the shape of our dataset(number of rows and number of columns)

# %%
df.shape
# Out:
# (7, 3)

# %%
print("number of rows:", df.shape[0])
print("number of columns:", df.shape[1])
# Out:
# number of rows: 7
# number of columns: 3

# %% [markdown]
# 4.get information about our dataset like total number of rows total number of columns , datatypes of each columns and memory requirements

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# 5.check null values

# %%
df.isnull()
# Out:
#     Name  Marks  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# 6.get overall statistics about this datastet

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6135619761967470084 = autoviz.get_registered_df('df_6135619761967470084')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6135619761967470084, *['Marks'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.describe(include='all')
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py", line 2466, in bar
#     bottom = y - height / 2
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %% [markdown]
# 7.find unique value of the gender column

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# 8.find number of unique value of the gender column

# %%
df['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# 9.display count of the gender column

# %%
df['Gender'].value_counts()
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %% [markdown]
# 10.find the totall number of student having maks between 90 to 100(inclusive)usibg between method

# %%
df['Marks']
# Out:
# 0    98
# 1    89
# 2    99
# 3    87
# 4    90
# 5    83
# 6    99
# Name: Marks, dtype: int64

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %%
df[(df['Marks']>=90) & (df['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df[(df['Marks']>=90) & (df['Marks']<=100)] )
# Out:
# 4

# %% [markdown]
# 11.find the aveg marks

# %%
df['Marks'].mean()
# Out:
# 92.14285714285714

# %%
df['Marks'].min()
# Out:
# 83

# %%
df['Marks'].max()
# Out:
# 99

# %% [markdown]
# 12.use apply method

# %%
df['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df['half marks']=df['Marks'].apply(lambda x:x/2)

# %%
df
# Out:
#       Name  Marks  Gender  half marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %% [markdown]
# 13. map ()

# %%
df['Gender'].map({
           'Male':1,
           'Female':0
})
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Gender, dtype: int64

# %%
df['SEX']=df['Gender'].map({
           'Male':1,
           'Female':0
})

# %%
df
# Out:
#       Name  Marks  Gender  half marks  SEX
# 0  Priyang     98    Male        49.0    1
# 1   Aadhya     89  Female        44.5    0
# 2   Krisha     99  Female        49.5    0
# 3   Vedant     87    Male        43.5    1
# 4   Parshv     90    Male        45.0    1
# 5   Mittal     83  Female        41.5    0
# 6  Archana     99  Female        49.5    0

# %% [markdown]
# 14.drop the column

# %%
df.drop('SEX', axis=1 , inplace=True)

# %%
df
# Out:
#       Name  Marks  Gender  half marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %% [markdown]
# 15.print the name of the columns

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'half marks'], dtype='object')

# %% [markdown]
# 16. sort the dataframe as per mark colums

# %%
df
# Out:
#       Name  Marks  Gender  half marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df.sort_values(by='Marks',ascending=False)
# Out:
#       Name  Marks  Gender  half marks
# 2   Krisha     99  Female        49.5
# 6  Archana     99  Female        49.5
# 0  Priyang     98    Male        49.0
# 4   Parshv     90    Male        45.0
# 1   Aadhya     89  Female        44.5
# 3   Vedant     87    Male        43.5
# 5   Mittal     83  Female        41.5

# %% [markdown]
# 16. display name and makrs of the female students

# %%
df
# Out:
#       Name  Marks  Gender  half marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df[df['Gender']=='Female']
# Out:
#       Name  Marks  Gender  half marks
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df[df['Gender']=='Female'].max()
# Out:
# Name          Mittal
# Marks             99
# Gender        Female
# half marks      49.5
# dtype: object

# %%
df[df['Gender']=='Female'].min()
# Out:
# Name          Aadhya
# Marks             83
# Gender        Female
# half marks      41.5
# dtype: object
